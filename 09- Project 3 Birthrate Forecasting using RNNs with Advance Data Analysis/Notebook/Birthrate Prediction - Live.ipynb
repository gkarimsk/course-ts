# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Import Dataset
df=pd.read_csv('BirthR.csv')

# %%
# g = df.groupby('Date', as_index=False).size().sort_values(by='size', ascending=False)
# g

# %%
#year_sum=df.groupby("year", as_index=False).agg({'births':['mean','sum']})
year_sum=df.groupby("year", as_index=False).agg(Biths_avg=('births','mean'), Births_sum=('births','sum'))
year_sum
# Out:
#     year     Biths_avg  Births_sum
# 0   1994  10829.498630     3952767
# 1   1995  10683.805479     3899589
# 2   1996  10632.497268     3891494
# 3   1997  10632.586301     3880894
# 4   1998  10798.775342     3941553
# 5   1999  10847.717808     3959417
# 6   2000  11089.655738     4058814
# 7   2001  11029.953425     4025933
# 8   2002  11018.427397     4021726
# 9   2003  11205.342466     4089950
# 10  2004  11439.516393     4186863
# 11  2005  11539.564384     4211941
# 12  2006  11877.134247     4335154
# 13  2007  12002.147945     4380784
# 14  2008  11777.969945     4310737
# 15  2009  11482.167123     4190991
# 16  2010  11112.260274     4055975
# 17  2011  10977.830137     4006908
# 18  2012  10931.333333     4000868
# 19  2013  10885.854795     3973337
# 20  2014  10987.758904     4010532

# %%
df.head()
# Out:
#        Date  births  year  month  date_of_month  day_of_week
# 0  1/1/1994    8096  1994      1              1            6
# 1  1/2/1994    7772  1994      1              2            7
# 2  1/3/1994   10142  1994      1              3            1
# 3  1/4/1994   11248  1994      1              4            2
# 4  1/5/1994   11053  1994      1              5            3

# %%
df.tail()
# Out:
#             Date  births  year  month  date_of_month  day_of_week
# 7665  12/27/2014    8656  2014     12             27            6
# 7666  12/28/2014    7724  2014     12             28            7
# 7667  12/29/2014   12811  2014     12             29            1
# 7668  12/30/2014   13634  2014     12             30            2
# 7669  12/31/2014   11990  2014     12             31            3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7670 entries, 0 to 7669
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           7670 non-null   object
#  1   births         7670 non-null   int64
#  2   year           7670 non-null   int64
#  3   month          7670 non-null   int64
#  4   date_of_month  7670 non-null   int64
#  5   day_of_week    7670 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 359.7+ KB

# %%
# birthrate according to year
#Bar plot (babies per year)
plt.figure(figsize=(18,5))
dist1=df.groupby("year")["births"].mean()
dist1.plot(kind='bar', rot=2)
plt.xlabel("Year", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Years Distribution", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,4))
year_sum=df.groupby("year")[['births']].sum()
plt.plot(year_sum,linewidth=3,color="r")
plt.xlabel("Year", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(range(1994,2015,1),fontsize=12)
plt.yticks(fontsize=12)
plt.title("Birth rate 1994-2014", fontsize=16,color="r")
plt.show()

# %%
#distribution of birth per month
#birth rate per month
plt.figure(figsize=(15,7))
dist1=df.groupby("month")["births"].mean()

dist1.plot(kind='bar', rot=0)
plt.xlabel("months",fontsize=12,color="r")
plt.ylabel("births", fontsize=12,color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("month's distribution", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,4))
mon_sum=df.groupby("month")[['births']].sum()
plt.plot(mon_sum,linewidth=3,color="r")
plt.xlabel("Year", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Birth rate per month 1994-2014", fontsize=16,color="r")
plt.show()

# %%
#distribution of birth per week days
#birth rate per week days

plt.figure(figsize=(15,7))
dist1=df.groupby("day_of_week")["births"].mean()

dist1.plot(kind='bar', rot=0)
plt.xlabel("day of week",fontsize=12,color="r")
plt.ylabel("births", fontsize=12,color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Weekday's distribution", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,4))
week_sum=df.groupby("day_of_week")[['births']].sum()
plt.plot(week_sum,linewidth=3,color="r")
plt.xlabel("Year", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Birth rate per week 1994-2014", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,7))
dist1=df.groupby("date_of_month")["births"].mean()

dist1.plot(kind='bar', rot=0)
plt.xlabel("day of month",fontsize=12,color="r")
plt.ylabel("births", fontsize=12,color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Month's distribution", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,4))
Date_month_sum=df.groupby("date_of_month")[['births']].sum()
plt.plot(Date_month_sum,linewidth=3,color="r")
plt.xlabel("days of month", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Birth rate per day of month 1994-2014", fontsize=16,color="r")
plt.show()

# %%
#Range of birthrate per year

plt.figure(figsize=(18,5))
year_min=df.groupby("year")[['births']].min()
year_max=df.groupby("year")[['births']].max()
year_mean=df.groupby("year")[['births']].mean()
year_std=df.groupby("year")[['births']].std()

x=year_mean.index
plt.plot(year_max,linewidth=3,label="Max",color="b")
plt.plot(year_mean,linewidth=3,label="Average",color="g")
plt.plot(year_min,linewidth=3,label="Min",color="r")
plt.plot(year_std,linewidth=3,label="STD",color="k")

plt.fill_between(x,year_min["births"],year_max["births"],alpha=0.3, facecolor='yellow')
plt.xticks(range(1994,2015,1), fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel("Years", fontsize=12,color="r")
plt.ylabel("Value", fontsize=12,color="r")
plt.title("range of birth rate", fontsize=16,color="r")
plt.legend(loc='best')
plt.draw()

# %%
df.describe()
# Out:
#              births         year        month  date_of_month  day_of_week
# count   7670.000000  7670.000000  7670.000000    7670.000000  7670.000000
# mean   11132.493742  2004.000000     6.523077      15.729205     3.999870
# std     2172.398653     6.055444     3.448888       8.800483     2.000359
# min     5728.000000  1994.000000     1.000000       1.000000     1.000000
# 25%     8759.000000  1999.000000     4.000000       8.000000     2.000000
# 50%    11941.000000  2004.000000     7.000000      16.000000     4.000000
# 75%    12754.750000  2009.000000    10.000000      23.000000     6.000000
# max    16081.000000  2014.000000    12.000000      31.000000     7.000000

# %%
corr = df.select_dtypes(include=np.number).corr()

# %%
corr_v = 0.6

corr.style.apply(lambda x: ["background-color: red" 
                          if (v > corr_v or v < -corr_v) and (v != 1)
                          else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_79d6a_row0_col4, #T_79d6a_row4_col0 {
#   background-color: red;
# }
# </style>
# <table id="T_79d6a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79d6a_level0_col0" class="col_heading level0 col0" >births</th>
#       <th id="T_79d6a_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_79d6a_level0_col2" class="col_heading level0 col2" >month</th>
#       <th id="T_79d6a_level0_col3" class="col_heading level0 col3" >date_of_month</th>
#       <th id="T_79d6a_level0_col4" class="col_heading level0 col4" >day_of_week</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79d6a_level0_row0" class="row_heading level0 row0" >births</th>
#       <td id="T_79d6a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_79d6a_row0_col1" class="data row0 col1" >0.075968</td>
#       <td id="T_79d6a_row0_col2" class="data row0 col2" >0.060168</td>
#       <td id="T_79d6a_row0_col3" class="data row0 col3" >-0.003190</td>
#       <td id="T_79d6a_row0_col4" class="data row0 col4" >-0.674588</td>
#     </tr>
#     <tr>
#       <th id="T_79d6a_level0_row1" class="row_heading level0 row1" >year</th>
#       <td id="T_79d6a_row1_col0" class="data row1 col0" >0.075968</td>
#       <td id="T_79d6a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_79d6a_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_79d6a_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_79d6a_row1_col4" class="data row1 col4" >-0.000344</td>
#     </tr>
#     <tr>
#       <th id="T_79d6a_level0_row2" class="row_heading level0 row2" >month</th>
#       <td id="T_79d6a_row2_col0" class="data row2 col0" >0.060168</td>
#       <td id="T_79d6a_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_79d6a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_79d6a_row2_col3" class="data row2 col3" >0.010587</td>
#       <td id="T_79d6a_row2_col4" class="data row2 col4" >0.000104</td>
#     </tr>
#     <tr>
#       <th id="T_79d6a_level0_row3" class="row_heading level0 row3" >date_of_month</th>
#       <td id="T_79d6a_row3_col0" class="data row3 col0" >-0.003190</td>
#       <td id="T_79d6a_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_79d6a_row3_col2" class="data row3 col2" >0.010587</td>
#       <td id="T_79d6a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_79d6a_row3_col4" class="data row3 col4" >0.000072</td>
#     </tr>
#     <tr>
#       <th id="T_79d6a_level0_row4" class="row_heading level0 row4" >day_of_week</th>
#       <td id="T_79d6a_row4_col0" class="data row4 col0" >-0.674588</td>
#       <td id="T_79d6a_row4_col1" class="data row4 col1" >-0.000344</td>
#       <td id="T_79d6a_row4_col2" class="data row4 col2" >0.000104</td>
#       <td id="T_79d6a_row4_col3" class="data row4 col3" >0.000072</td>
#       <td id="T_79d6a_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (7670, 6)

# %%
df.columns
# Out:
# Index(['Date', 'births', 'year', 'month', 'date_of_month', 'day_of_week'], dtype='object')

# %%
df.isnull().any()
# Out:
# Date             False
# births           False
# year             False
# month            False
# date_of_month    False
# day_of_week      False
# dtype: bool

# %%
#stationarity check
from statsmodels.tsa.stattools import adfuller

# %%
# p-value deve essere minore di 0.05

X= df.births.values
result=adfuller(X)
print('ADF Statistics:%f'%result[0])
print('p-value:%f'%result[1])
print('critical values')
for key,value in result[4].items():
    print('\t%s: %.3f'%(key,value))
# Out:
# ADF Statistics:-4.085969
# p-value:0.001022
# critical values
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
df['Date']
# Out:
# 0         1/1/1994
# 1         1/2/1994
# 2         1/3/1994
# 3         1/4/1994
# 4         1/5/1994
#            ...
# 7665    12/27/2014
# 7666    12/28/2014
# 7667    12/29/2014
# 7668    12/30/2014
# 7669    12/31/2014
# Name: Date, Length: 7670, dtype: object

# %%
train_dates=pd.to_datetime(df['Date'])
train_dates
# Out:
# 0      1994-01-01
# 1      1994-01-02
# 2      1994-01-03
# 3      1994-01-04
# 4      1994-01-05
#           ...
# 7665   2014-12-27
# 7666   2014-12-28
# 7667   2014-12-29
# 7668   2014-12-30
# 7669   2014-12-31
# Name: Date, Length: 7670, dtype: datetime64[ns]

# %%
cols= list(df)[1:2]
cols
# Out:
# ['births']

# %%
df_for_training=df[cols].astype(float)

# %%
df_for_training
# Out:
#        births
# 0      8096.0
# 1      7772.0
# 2     10142.0
# 3     11248.0
# 4     11053.0
# ...       ...
# 7665   8656.0
# 7666   7724.0
# 7667  12811.0
# 7668  13634.0
# 7669  11990.0
#
# [7670 rows x 1 columns]

# %%
df_for_plot=df_for_training
df_for_plot.plot.line(figsize=(18,8))
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaler=scaler.fit(df_for_training)
df_for_training_scaled=scaler.transform(df_for_training)

df_for_training_scaled
# Out:
# array([[-1.39785196],
#        [-1.54700558],
#        [-0.45597447],
#        ...,
#        [ 0.7727015 ],
#        [ 1.15157011],
#        [ 0.39475359]])

# %%
pd.DataFrame(df_for_training_scaled).plot.line(figsize=(18,8))
# Out:
# <Axes: >

# %%
df_for_training.shape[1]
# Out:
# 1

# %%
trainX=[]
trainY=[]

n_future = 100
n_past = 20

for i in range(n_past, len(df_for_training_scaled) - n_future +1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])
    
trainX, trainY =np.array(trainX), np.array(trainY)

print('trainX shape==={}.'.format(trainX.shape))
print('trainY shape==={}.'.format(trainY.shape))
# Out:
# trainX shape===(7551, 20, 1).
# trainY shape===(7551, 1).

# %%
from keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional

# %%
model=Sequential()

model.add(LSTM(32,activation='relu', input_shape=(trainX.shape[1],trainX.shape[2])))
model.add(Dropout(0.5))

model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 20, 32)            4352
#
#  dropout_2 (Dropout)         (None, 20, 32)            0
#
#  dense_1 (Dense)             (None, 20, 1)             33
#
# =================================================================
# Total params: 4385 (17.13 KB)
# Trainable params: 4385 (17.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model=Sequential()

model.add(LSTM(32,activation='relu', input_shape=(trainX.shape[1],trainX.shape[2]),return_sequences=True))
model.add(Dropout(0.5))

model.add(LSTM(32,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 6
#       3 model.add(LSTM(32,activation='relu', input_shape=(trainX.shape[1],trainX.shape[2])))
#       4 model.add(Dropout(0.5))
# ----> 6 model.add(LSTM(32,activation='relu'))
#       7 model.add(Dropout(0.5))
#       9 model.add(Dense(trainY.shape[1]))
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\tensorflow\python\trackable\base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\keras\src\engine\input_spec.py:235, in assert_input_compatibility(input_spec, inputs, layer_name)
#     233     ndim = shape.rank
#     234     if ndim != spec.ndim:
# --> 235         raise ValueError(
#     236             f'Input {input_index} of layer "{layer_name}" '
#     237             "is incompatible with the layer: "
#     238             f"expected ndim={spec.ndim}, found ndim={ndim}. "
#     239             f"Full shape received: {tuple(shape)}"
#     240         )
#     241 if spec.max_ndim is not None:
#     242     ndim = x.shape.rank
#
# ValueError: Input 0 of layer "lstm_4" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 32)

# %%
model=Sequential()

# model.add(LSTM(32,activation='relu', input_shape=(trainX.shape[1],trainX.shape[2]),return_sequences=True))
model.add(Bidirectional(LSTM(32, return_sequences=True),input_shape=(trainX.shape[1],trainX.shape[2])))
model.add(Dropout(0.5))

model.add(Bidirectional(LSTM(32)))
model.add(Dropout(0.5))

model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 20, 64)            8704
#  al)
#
#  dropout (Dropout)           (None, 20, 64)            0
#
#  bidirectional_1 (Bidirecti  (None, 64)                24832
#  onal)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 33601 (131.25 KB)
# Trainable params: 33601 (131.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#12m
history=model.fit(trainX, trainY, epochs=100, batch_size=10, validation_split=0.1,verbose=1)
# Out:
# Epoch 1/100
# 680/680 [==============================] - 4s 4ms/step - loss: 0.6940 - val_loss: 0.3303
# Epoch 2/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.3353 - val_loss: 0.2969
# Epoch 3/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2977 - val_loss: 0.2826
# Epoch 4/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2839 - val_loss: 0.2789
# Epoch 5/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2761 - val_loss: 0.2800
# Epoch 6/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2711 - val_loss: 0.2605
# Epoch 7/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2697 - val_loss: 0.2536
# Epoch 8/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2670 - val_loss: 0.2644
# Epoch 9/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2648 - val_loss: 0.2797
# Epoch 10/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2644 - val_loss: 0.2645
# Epoch 11/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2608 - val_loss: 0.2537
# Epoch 12/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2597 - val_loss: 0.2501
# Epoch 13/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2563 - val_loss: 0.2586
# Epoch 14/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2525 - val_loss: 0.2742
# Epoch 15/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2504 - val_loss: 0.2299
# Epoch 16/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2459 - val_loss: 0.2253
# Epoch 17/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2465 - val_loss: 0.2375
# Epoch 18/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2425 - val_loss: 0.2389
# Epoch 19/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2419 - val_loss: 0.2275
# Epoch 20/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2406 - val_loss: 0.2537
# Epoch 21/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2425 - val_loss: 0.2348
# Epoch 22/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2405 - val_loss: 0.2400
# Epoch 23/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2409 - val_loss: 0.2312
# Epoch 24/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2379 - val_loss: 0.2338
# Epoch 25/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2356 - val_loss: 0.2197
# Epoch 26/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2352 - val_loss: 0.2187
# Epoch 27/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2343 - val_loss: 0.2358
# Epoch 28/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2322 - val_loss: 0.2137
# Epoch 29/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2353 - val_loss: 0.2211
# Epoch 30/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2338 - val_loss: 0.2114
# Epoch 31/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2331 - val_loss: 0.2347
# Epoch 32/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2310 - val_loss: 0.2250
# Epoch 33/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2323 - val_loss: 0.2278
# Epoch 34/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2312 - val_loss: 0.2218
# Epoch 35/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2325 - val_loss: 0.2227
# Epoch 36/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2281 - val_loss: 0.2300
# Epoch 37/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2292 - val_loss: 0.2282
# Epoch 38/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2293 - val_loss: 0.2370
# Epoch 39/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2284 - val_loss: 0.2088
# Epoch 40/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2297 - val_loss: 0.2158
# Epoch 41/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2285 - val_loss: 0.2074
# Epoch 42/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2277 - val_loss: 0.2509
# Epoch 43/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2289 - val_loss: 0.2018
# Epoch 44/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2268 - val_loss: 0.2305
# Epoch 45/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2254 - val_loss: 0.2252
# Epoch 46/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2270 - val_loss: 0.2173
# Epoch 47/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2257 - val_loss: 0.2071
# Epoch 48/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2267 - val_loss: 0.1991
# Epoch 49/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2237 - val_loss: 0.2144
# Epoch 50/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2252 - val_loss: 0.2087
# Epoch 51/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2243 - val_loss: 0.2164
# Epoch 52/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2240 - val_loss: 0.2273
# Epoch 53/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2263 - val_loss: 0.2099
# Epoch 54/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2247 - val_loss: 0.2139
# Epoch 55/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2236 - val_loss: 0.2034
# Epoch 56/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2243 - val_loss: 0.2206
# Epoch 57/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2201 - val_loss: 0.2032
# Epoch 58/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2229 - val_loss: 0.2070
# Epoch 59/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2217 - val_loss: 0.1936
# Epoch 60/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2214 - val_loss: 0.2156
# Epoch 61/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2227 - val_loss: 0.1984
# Epoch 62/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2220 - val_loss: 0.2097
# Epoch 63/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2208 - val_loss: 0.1976
# Epoch 64/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2196 - val_loss: 0.2060
# Epoch 65/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2222 - val_loss: 0.2160
# Epoch 66/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2232 - val_loss: 0.2258
# Epoch 67/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2202 - val_loss: 0.2100
# Epoch 68/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2192 - val_loss: 0.1989
# Epoch 69/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2194 - val_loss: 0.2054
# Epoch 70/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2200 - val_loss: 0.1960
# Epoch 71/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2187 - val_loss: 0.2029
# Epoch 72/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2201 - val_loss: 0.1921
# Epoch 73/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2199 - val_loss: 0.2358
# Epoch 74/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2199 - val_loss: 0.2028
# Epoch 75/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2193 - val_loss: 0.2249
# Epoch 76/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2252 - val_loss: 0.2026
# Epoch 77/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2181 - val_loss: 0.2200
# Epoch 78/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2186 - val_loss: 0.2155
# Epoch 79/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2172 - val_loss: 0.2061
# Epoch 80/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2174 - val_loss: 0.2303
# Epoch 81/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2186 - val_loss: 0.1980
# Epoch 82/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2180 - val_loss: 0.2030
# Epoch 83/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2192 - val_loss: 0.1961
# Epoch 84/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2190 - val_loss: 0.1955
# Epoch 85/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2169 - val_loss: 0.2059
# Epoch 86/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2172 - val_loss: 0.2008
# Epoch 87/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2160 - val_loss: 0.2002
# Epoch 88/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2174 - val_loss: 0.2167
# Epoch 89/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2158 - val_loss: 0.2022
# Epoch 90/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2161 - val_loss: 0.2107
# Epoch 91/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2193 - val_loss: 0.2363
# Epoch 92/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2169 - val_loss: 0.2039
# Epoch 93/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2163 - val_loss: 0.2080
# Epoch 94/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2165 - val_loss: 0.1993
# Epoch 95/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2150 - val_loss: 0.1931
# Epoch 96/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2173 - val_loss: 0.2040
# Epoch 97/100
# 680/680 [==============================] - 3s 5ms/step - loss: 0.2158 - val_loss: 0.2109
# Epoch 98/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2143 - val_loss: 0.1990
# Epoch 99/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2153 - val_loss: 0.1953
# Epoch 100/100
# 680/680 [==============================] - 3s 4ms/step - loss: 0.2169 - val_loss: 0.2037

# %%
plt.plot(history.history['loss'],label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
us_bd = CustomBusinessDay(calendar=USFederalHolidayCalendar())

# %%
n_past = 10
n_days_for_prediction=100  

predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction, freq=us_bd).tolist()

# %%
prediction = model.predict(trainX[-n_days_for_prediction:])
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
prediction_copies = np.repeat(prediction, df_for_training.shape[1], axis=-1)
prediction_copies.shape
# Out:
# (100, 20, 1)

# %%
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\sklearn\preprocessing\_data.py:1048, in StandardScaler.inverse_transform(self, X, copy)
#    1045 check_is_fitted(self)
#    1047 copy = copy if copy is not None else self.copy
# -> 1048 X = check_array(
#    1049     X,
#    1050     accept_sparse="csr",
#    1051     copy=copy,
#    1052     dtype=FLOAT_DTYPES,
#    1053     force_all_finite="allow-nan",
#    1054 )
#    1056 if sparse.issparse(X):
#    1057     if self.with_mean:
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\sklearn\utils\validation.py:951, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     946     raise ValueError(
#     947         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     948         "Convert your data to numeric values explicitly instead."
#     949     )
#     950 if not allow_nd and array.ndim >= 3:
# --> 951     raise ValueError(
#     952         "Found array with dim %d. %s expected <= 2."
#     953         % (array.ndim, estimator_name)
#     954     )
#     956 if force_all_finite:
#     957     _assert_all_finite(
#     958         array,
#     959         input_name=input_name,
#     960         estimator_name=estimator_name,
#     961         allow_nan=force_all_finite == "allow-nan",
#     962     )
#
# ValueError: Found array with dim 3. None expected <= 2.

# %%
forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i.date())
    
df_forecast = pd.DataFrame({'Date':np.array(forecast_dates), 'births':y_pred_future})
df_forecast['Date']=pd.to_datetime(df_forecast['Date'])

# %%
original = df[['Date', 'births']]
original['Date']=pd.to_datetime(original['Date'])
original = original.loc[original['Date'] >= '2013-12-12']
import seaborn as sns
sns.set(rc = {'figure.figsize':(15,8)})
sns.lineplot(original['Date'], original['births'])
sns.lineplot(df_forecast['Date'], df_forecast['births'])
