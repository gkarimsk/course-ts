# %% [markdown]
# # Microsoft Stock Prediction Using LSTM, STACKED LSTM and BiDirectional LSTM

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Dataset

# %%
df=pd.read_csv('MSFT.csv')

# %%
df.head()
# Out:
#        Date       Open       High        Low      Close  Adj_Close    Volume
# 0  1/3/2017  62.790001  62.840000  62.130001  62.580002  57.807823  20694100
# 1  1/4/2017  62.480000  62.750000  62.119999  62.299999  57.549179  21340000
# 2  1/5/2017  62.189999  62.660000  62.029999  62.299999  57.549179  24876000
# 3  1/6/2017  62.299999  63.150002  62.040001  62.840000  58.047993  19922900
# 4  1/9/2017  62.759998  63.080002  62.540001  62.639999  57.863243  20382700

# %%
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj_Close  \
# 1421  8/25/2022  277.329987  279.019989  274.519989  278.850006  278.850006
# 1422  8/26/2022  279.079987  280.339996  267.980011  268.089996  268.089996
# 1423  8/29/2022  265.850006  267.399994  263.850006  265.230011  265.230011
# 1424  8/30/2022  266.670013  267.049988  260.660004  262.970001  262.970001
# 1425  8/31/2022  265.390015  267.109985  261.329987  261.470001  261.470001
#
#         Volume
# 1421  16583400
# 1422  27532500
# 1423  20338500
# 1424  22767100
# 1425  24728900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1426 non-null   object
#  1   Open       1426 non-null   float64
#  2   High       1426 non-null   float64
#  3   Low        1426 non-null   float64
#  4   Close      1426 non-null   float64
#  5   Adj_Close  1426 non-null   float64
#  6   Volume     1426 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 78.1+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj_Close  \
# count  1426.000000  1426.000000  1426.000000  1426.000000  1426.000000
# mean    169.561353   171.243268   167.753464   169.588822   165.923293
# std      82.510456    83.402749    81.533050    82.509972    83.539829
# min      62.189999    62.660000    61.950001    62.299999    57.549179
# 25%      98.414999    99.912503    97.302502    98.444999    93.971957
# 50%     142.135002   144.700005   139.805001   141.455002   137.402313
# 75%     243.832501   245.525005   241.487496   243.752502   240.720517
# max     344.619995   349.670013   342.200012   343.109985   340.882782
#
#              Volume
# count  1.426000e+03
# mean   2.890647e+07
# std    1.262903e+07
# min    7.425600e+06
# 25%    2.075820e+07
# 50%    2.568230e+07
# 75%    3.318965e+07
# max    1.112421e+08

# %% [markdown]
# # Compute Mean, STD, Min and Max Values

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj_Close', 'Volume'], dtype='object')

# %%
df.shape
# Out:
# (1426, 7)

# %%
df.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj_Close    False
# Volume       False
# dtype: bool

# %%
df.isnull()
# Out:
#        Date   Open   High    Low  Close  Adj_Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 1421  False  False  False  False  False      False   False
# 1422  False  False  False  False  False      False   False
# 1423  False  False  False  False  False      False   False
# 1424  False  False  False  False  False      False   False
# 1425  False  False  False  False  False      False   False
#
# [1426 rows x 7 columns]

# %% [markdown]
# # Visualize the overall trend of the Dataset

# %%
plt.figure(num=None, figsize=(30,10), dpi=80, facecolor='w',edgecolor='k')
plt.title('Open', fontsize=30)
plt.plot(df.Open)

plt.figure(num=None, figsize=(30,10), dpi=80, facecolor='w',edgecolor='k')
plt.title('High', fontsize=30)
plt.plot(df.High)

plt.figure(num=None, figsize=(30,10), dpi=80, facecolor='w',edgecolor='k')
plt.title('Low', fontsize=30)
plt.plot(df.Low)

plt.figure(num=None, figsize=(30,10), dpi=80, facecolor='w',edgecolor='k')
plt.title('Close', fontsize=30)
plt.plot(df.Close)

plt.figure(num=None, figsize=(30,10), dpi=80, facecolor='w',edgecolor='k')
plt.title('Adj_close', fontsize=30)
plt.plot(df.Adj_Close)

plt.figure(num=None, figsize=(30,10), dpi=80, facecolor='w',edgecolor='k')
plt.title('Volume', fontsize=30)
plt.plot(df.Volume)

# %% [markdown]
# # Line Plot

# %%
df.set_index('Date',inplace=True)
df.head()
# Out:
#                Open       High        Low      Close  Adj_Close    Volume
# Date
# 1/3/2017  62.790001  62.840000  62.130001  62.580002  57.807823  20694100
# 1/4/2017  62.480000  62.750000  62.119999  62.299999  57.549179  21340000
# 1/5/2017  62.189999  62.660000  62.029999  62.299999  57.549179  24876000
# 1/6/2017  62.299999  63.150002  62.040001  62.840000  58.047993  19922900
# 1/9/2017  62.759998  63.080002  62.540001  62.639999  57.863243  20382700

# %%
df['Volume'].plot(kind='line',figsize=(14,8))

plt.title('Overview of Stocks of microsoft')
plt.ylabel('Value')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# # Area Plot

# %%
df['Open'].plot(kind='area',stacked=True,figsize=(20,10))

plt.title('Microsoft stocks on opening')
plt.ylabel('Opening Value')
plt.xlabel('Date')

plt.show()

# %%
df['Volume'].plot(kind='area',stacked=True,figsize=(20,10))

plt.title('Microsoft stocks Volume')
plt.ylabel('Volume')
plt.xlabel('Date')

plt.show()

# %% [markdown]
# # Visualize Correlation, STD and Mean

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig=plt.figure(figsize=(12,7))
layout=(2,2)
hist_ax=plt.subplot2grid(layout,(0,0))
ac_ax=plt.subplot2grid(layout,(1,0))
hist_std_ax= plt.subplot2grid(layout,(0,1))
mean_ax=plt.subplot2grid(layout,(1,1))


df.Volume.hist(ax=hist_ax)
hist_ax.set_title("Original Histogram")

series= df.Volume[:365]

plot_acf(series, lags=30, ax=ac_ax)
ac_ax.set_title("Autocorrelation")

mm= df.Volume.rolling(7).std()
mm.hist(ax=hist_std_ax)
hist_std_ax.set_title("Standard Deviation")

mm= df.Volume.rolling(30).mean()
mm.hist(ax=mean_ax)
mean_ax.set_title("Mean Over Time")
# Out:
# Text(0.5, 1.0, 'Mean Over Time')

# %% [markdown]
# # Check Stationarity

# %%
from statsmodels.tsa.stattools import adfuller

# %%
X=df.Volume.values
result=adfuller(X)

# %%
print('ADF Statistics:%f'%result[0])
print('p-value:%f'%result[1])

print('Critical Values')
for key, value in result[4].items():
    print('\t%s: %.3f'%(key,value))
# Out:
# ADF Statistics:-5.557343
# p-value:0.000002
# Critical Values
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %%
df.head()
# Out:
#                Open       High        Low      Close  Adj_Close    Volume
# Date
# 1/3/2017  62.790001  62.840000  62.130001  62.580002  57.807823  20694100
# 1/4/2017  62.480000  62.750000  62.119999  62.299999  57.549179  21340000
# 1/5/2017  62.189999  62.660000  62.029999  62.299999  57.549179  24876000
# 1/6/2017  62.299999  63.150002  62.040001  62.840000  58.047993  19922900
# 1/9/2017  62.759998  63.080002  62.540001  62.639999  57.863243  20382700

# %% [markdown]
# # 1. Volume Forecasting using LSTM Model

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj_Close  \
# 0      1/3/2017   62.790001   62.840000   62.130001   62.580002   57.807823
# 1      1/4/2017   62.480000   62.750000   62.119999   62.299999   57.549179
# 2      1/5/2017   62.189999   62.660000   62.029999   62.299999   57.549179
# 3      1/6/2017   62.299999   63.150002   62.040001   62.840000   58.047993
# 4      1/9/2017   62.759998   63.080002   62.540001   62.639999   57.863243
# ...         ...         ...         ...         ...         ...         ...
# 1421  8/25/2022  277.329987  279.019989  274.519989  278.850006  278.850006
# 1422  8/26/2022  279.079987  280.339996  267.980011  268.089996  268.089996
# 1423  8/29/2022  265.850006  267.399994  263.850006  265.230011  265.230011
# 1424  8/30/2022  266.670013  267.049988  260.660004  262.970001  262.970001
# 1425  8/31/2022  265.390015  267.109985  261.329987  261.470001  261.470001
#
#         Volume
# 0     20694100
# 1     21340000
# 2     24876000
# 3     19922900
# 4     20382700
# ...        ...
# 1421  16583400
# 1422  27532500
# 1423  20338500
# 1424  22767100
# 1425  24728900
#
# [1426 rows x 7 columns]

# %%
train_dates=pd.to_datetime(df['Date'])
train_dates
# Out:
# 0      2017-01-03
# 1      2017-01-04
# 2      2017-01-05
# 3      2017-01-06
# 4      2017-01-09
#           ...
# 1421   2022-08-25
# 1422   2022-08-26
# 1423   2022-08-29
# 1424   2022-08-30
# 1425   2022-08-31
# Name: Date, Length: 1426, dtype: datetime64[ns]

# %%
cols=list(df)[6:7]
cols
# Out:
# ['Volume']

# %%
df_for_training=df[cols].astype(float)
df_for_training
# Out:
#           Volume
# 0     20694100.0
# 1     21340000.0
# 2     24876000.0
# 3     19922900.0
# 4     20382700.0
# ...          ...
# 1421  16583400.0
# 1422  27532500.0
# 1423  20338500.0
# 1424  22767100.0
# 1425  24728900.0
#
# [1426 rows x 1 columns]

# %%
df_for_plot=df_for_training
df_for_plot.plot.line(figsize=(15,8))
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler=scaler.fit(df_for_training)
df_for_training_scaled=scaler.transform(df_for_training)

# %%
df_for_training_scaled
# Out:
# array([[-0.65050546],
#        [-0.59934343],
#        [-0.31925529],
#        ...,
#        [-0.6786727 ],
#        [-0.4863022 ],
#        [-0.33090715]])

# %%
print(df_for_training.shape)
# Out:
# (1426, 1)

# %%
trainX=[]
trainY=[]

n_future=1
n_past=25
for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i-n_past:i,0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i+n_future-1:i+n_future,0])

trainX,trainY=np.array(trainX), np.array(trainY)

print('trainX shape==={}.'.format(trainX.shape))
print('trainY shape==={}.'.format(trainY.shape))
# Out:
# trainX shape===(1401, 25, 1).
# trainY shape===(1401, 1).

# %%
from keras.models import Sequential

# %%
from tensorflow.keras.layers import LSTM, Dense, Activation, Dropout, Bidirectional, BatchNormalization, Embedding

# %%
model=Sequential()
model.add(Bidirectional(LSTM(32,activation='relu',return_sequences=True),input_shape=(trainX.shape[1],trainX.shape[2])))
model.add(Dropout(0.2))

model.add(Bidirectional(LSTM(32)))
model.add(Dropout(0.2))

model.add(Dense(trainY.shape[1]))
model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 25, 64)            8704
#  al)
#
#  dropout (Dropout)           (None, 25, 64)            0
#
#  bidirectional_1 (Bidirecti  (None, 64)                24832
#  onal)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 33601 (131.25 KB)
# Trainable params: 33601 (131.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history=model.fit(trainX,trainY,epochs=62,batch_size=16,validation_split=0.1,verbose=1)
# Out:
# Epoch 1/62
# 79/79 [==============================] - 6s 21ms/step - loss: 0.6967 - val_loss: 0.3601
# Epoch 2/62
# 79/79 [==============================] - 1s 11ms/step - loss: 0.5500 - val_loss: 0.3518
# Epoch 3/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.5348 - val_loss: 0.3691
# Epoch 4/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.5176 - val_loss: 0.3521
# Epoch 5/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.5023 - val_loss: 0.3306
# Epoch 6/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4896 - val_loss: 0.3242
# Epoch 7/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4998 - val_loss: 0.3192
# Epoch 8/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4721 - val_loss: 0.3202
# Epoch 9/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4728 - val_loss: 0.3143
# Epoch 10/62
# 79/79 [==============================] - 1s 15ms/step - loss: 0.4797 - val_loss: 0.3154
# Epoch 11/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.4794 - val_loss: 0.3082
# Epoch 12/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4644 - val_loss: 0.3174
# Epoch 13/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4658 - val_loss: 0.3105
# Epoch 14/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4510 - val_loss: 0.3053
# Epoch 15/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4657 - val_loss: 0.3080
# Epoch 16/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4567 - val_loss: 0.3072
# Epoch 17/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4495 - val_loss: 0.3187
# Epoch 18/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4717 - val_loss: 0.3183
# Epoch 19/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4373 - val_loss: 0.3056
# Epoch 20/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.4496 - val_loss: 0.3286
# Epoch 21/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4544 - val_loss: 0.3091
# Epoch 22/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4420 - val_loss: 0.3093
# Epoch 23/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4442 - val_loss: 0.3032
# Epoch 24/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.4372 - val_loss: 0.3072
# Epoch 25/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4338 - val_loss: 0.3114
# Epoch 26/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.4257 - val_loss: 0.3110
# Epoch 27/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.4366 - val_loss: 0.3042
# Epoch 28/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4325 - val_loss: 0.3077
# Epoch 29/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4342 - val_loss: 0.3093
# Epoch 30/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4260 - val_loss: 0.3107
# Epoch 31/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4418 - val_loss: 0.3149
# Epoch 32/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4460 - val_loss: 0.3067
# Epoch 33/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4186 - val_loss: 0.3108
# Epoch 34/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4218 - val_loss: 0.3100
# Epoch 35/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4237 - val_loss: 0.3137
# Epoch 36/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4281 - val_loss: 0.3158
# Epoch 37/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4109 - val_loss: 0.3189
# Epoch 38/62
# 79/79 [==============================] - 1s 12ms/step - loss: 0.4147 - val_loss: 0.3374
# Epoch 39/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4054 - val_loss: 0.3083
# Epoch 40/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4098 - val_loss: 0.3111
# Epoch 41/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4137 - val_loss: 0.3142
# Epoch 42/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.4040 - val_loss: 0.3160
# Epoch 43/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3982 - val_loss: 0.3184
# Epoch 44/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4120 - val_loss: 0.3112
# Epoch 45/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4150 - val_loss: 0.3137
# Epoch 46/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.3996 - val_loss: 0.3200
# Epoch 47/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3948 - val_loss: 0.3051
# Epoch 48/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4010 - val_loss: 0.3109
# Epoch 49/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.4031 - val_loss: 0.3111
# Epoch 50/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.4033 - val_loss: 0.3097
# Epoch 51/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3894 - val_loss: 0.3100
# Epoch 52/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3861 - val_loss: 0.3158
# Epoch 53/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3827 - val_loss: 0.3335
# Epoch 54/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.3868 - val_loss: 0.3384
# Epoch 55/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3911 - val_loss: 0.3324
# Epoch 56/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3882 - val_loss: 0.3210
# Epoch 57/62
# 79/79 [==============================] - 1s 15ms/step - loss: 0.3820 - val_loss: 0.3201
# Epoch 58/62
# 79/79 [==============================] - 1s 15ms/step - loss: 0.3901 - val_loss: 0.3220
# Epoch 59/62
# 79/79 [==============================] - 1s 14ms/step - loss: 0.3788 - val_loss: 0.3152
# Epoch 60/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3946 - val_loss: 0.3171
# Epoch 61/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3868 - val_loss: 0.3086
# Epoch 62/62
# 79/79 [==============================] - 1s 13ms/step - loss: 0.3772 - val_loss: 0.3256

# %%
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar

# %%
from pandas.tseries.offsets import CustomBusinessDay

# %%
us_bd=CustomBusinessDay(calendar=USFederalHolidayCalendar())

# %%
n_past=10
n_days_for_prediction=100

# %%
predict_period_dates=pd.date_range(list(train_dates)[-n_past],periods=n_days_for_prediction,freq=us_bd).tolist()

# %%
prediction=model.predict(trainX[-n_days_for_prediction:])
# Out:
# 4/4 [==============================] - 1s 3ms/step

# %%
prediction_copies=np.repeat(prediction,df_for_training.shape[1],axis=-1)

prediction_copies.shape
# Out:
# (100, 1)

# %%
y_pred_future=scaler.inverse_transform(prediction_copies)[:,0]

# %%
forecast_dates=[]
for time_i in predict_period_dates:
    forecast_dates.append(time_i.date())
    
df_forecast=pd.DataFrame({'Date':np.array(forecast_dates), 'Volume':y_pred_future})
df_forecast['Date']=pd.to_datetime(df_forecast['Date'])

# %%
original=df[['Date','Volume']].copy()
original['Date']=pd.to_datetime(original['Date'])
original=original.loc[original['Date']>='2017-1-3']

import seaborn as sns
sns.set_theme(rc={'figure.figsize':(15,8)})
sns.lineplot(data = original, x='Date', y='Volume')
sns.lineplot(data = df_forecast, x='Date', y='Volume')
# Out:
# <Axes: xlabel='Date', ylabel='Volume'>

# %% [markdown]
# # 2- Volume Forecasting Using Stacked LSTM Model

# %% [markdown]
# # 3-BiLSTM
