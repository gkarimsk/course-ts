# %% [markdown]
# # Module-3
# **Basics of Data Manipulation in Time Series

# %% [markdown]
# # Part A- Overview of this Module

# %% [markdown]
# # Part B- Packages Installation
#
# 1.	Visit <a href="https://www.anaconda.com/products/distribution">here</a> to download Anaconda

# %% [markdown]
# # Part C- Basic Plotting and Data Visualization in Python

# %% [markdown]
# # 1- Basic matplotlib

# %% [markdown]
# # Install Dependencies

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Step-1: Load Dataset

# %%
df = pd.read_excel('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx',
                  sheet_name='Canada by Citizenship',
                  skiprows=range(20),
                  skipfooter=2)
print('Data is read into dataframe')

# %%
df

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.shape

# %%
df.describe()

# %%
df.columns

# %%
df.shape

# %%
df.isnull().any()

# %%
df.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)

# %%
df.head(2)

# %%
df.rename(columns={'OdName':'Country', 'AreaName':'Continent','RegName':'Region'},inplace=True)

# %%
df = df.set_index('Country')

# %%
df['Total'] = df[df.columns[~df.columns.isin(['Continent','Region','DevName'])]].sum(axis=1)

# %%
df.isnull().sum()

# %% [markdown]
# Pandas Indexing and Selection

# %%
#df.set_index('Country', inplace=True)

# %%
df
# Out:
#                Continent              Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
#                 1982  1983  1984  1985  1986  ...  2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
# ...              ...   ...   ...   ...   ...  ...   ...   ...   ...   ...
# Viet Nam        2162  3404  7583  5907  2741  ...  1852  3153  2574  1784
# Western Sahara     0     0     0     0     0  ...     0     1     0     0
# Yemen              1     6     0    18     7  ...   161   140   122   133
# Zambia            11     7    16     9    15  ...    91    77    71    64
# Zimbabwe         102    44    32    29    43  ...   615   454   663   611
#
#                 2009  2010  2011  2012  2013  Total
# Country
# Afghanistan     1746  1758  2203  2635  2004  58639
# Albania          716   561   539   620   603  15699
# Algeria         5393  4752  4325  3774  4331  69439
# American Samoa     0     0     0     0     0      6
# Andorra            0     0     0     1     1     15
# ...              ...   ...   ...   ...   ...    ...
# Viet Nam        2171  1942  1723  1731  2112  97146
# Western Sahara     0     0     0     0     0      2
# Yemen            128   211   160   174   217   2985
# Zambia            60   102    69    46    59   1677
# Zimbabwe         508   494   434   437   407   8598
#
# [195 rows x 38 columns]

# %%
df.loc['Algeria']
# Out:
# Continent                Africa
# Region          Northern Africa
# DevName      Developing regions
# 1980                         80
# 1981                         67
# 1982                         71
# 1983                         69
# 1984                         63
# 1985                         44
# 1986                         69
# 1987                        132
# 1988                        242
# 1989                        434
# 1990                        491
# 1991                        872
# 1992                        795
# 1993                        717
# 1994                        595
# 1995                       1106
# 1996                       2054
# 1997                       1842
# 1998                       2292
# 1999                       2389
# 2000                       2867
# 2001                       3418
# 2002                       3406
# 2003                       3072
# 2004                       3616
# 2005                       3626
# 2006                       4807
# 2007                       3623
# 2008                       4005
# 2009                       5393
# 2010                       4752
# 2011                       4325
# 2012                       3774
# 2013                       4331
# Total                     69439
# Name: Algeria, dtype: object

# %%
df.loc['Algeria',2013]

# %%
df.iloc[2,36]

# %% [markdown]
# # Visualizing Data using Matplotlib

# %%
df.columns
# Out:
# Index(['Continent',    'Region',   'DevName',        1980,        1981,
#               1982,        1983,        1984,        1985,        1986,
#               1987,        1988,        1989,        1990,        1991,
#               1992,        1993,        1994,        1995,        1996,
#               1997,        1998,        1999,        2000,        2001,
#               2002,        2003,        2004,        2005,        2006,
#               2007,        2008,        2009,        2010,        2011,
#               2012,        2013,     'Total'],
#       dtype='object')

# %%
year = list(range(1980,2014))

# %%
year
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
pakistan_data=df.loc['Pakistan',year]

# %%
pakistan_data.head()
# Out:
# 1980     978
# 1981     972
# 1982    1201
# 1983     900
# 1984     668
# Name: Pakistan, dtype: object

# %%
pakistan_data.plot()
plt.show()

# %%
pakistan_data.plot()
plt.title('Immigrants from Pakistan')
plt.ylabel('No of Immigrants')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# Multiple Countries

# %%
df.columns = list(map(str,df.columns))

# %%
years = list(map(str,range(1980, 2014)))
years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
df_PI= df.loc[['India','China'], years]

# %%
df_PI.plot(kind='line')
# Out:
# <Axes: xlabel='Country'>

# %%
plt.show()

# %%
df_PI=df_PI.transpose()

# %%
df_PI.head()
# Out:
# Country  India  China
# 1980      8880   5123
# 1981      8670   6682
# 1982      8147   3308
# 1983      7338   1863
# 1984      5704   1527

# %%
df_PI.index = df_PI.index.map(int)

# %%
df_PI.plot(kind='line')
plt.title('immigrants from china and india')
plt.ylabel('No of immigrants')
plt.xlabel('Years')
plt.show()

# %%
inplace=True
df.sort_values(by='Total', ascending=False, axis=0, inplace=True)

df_top5 = df.head(5)

# %%
df_top5
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# India                                               Developing regions   8880
# China                                               Developing regions   5123
# United Kingdom of Great Britain and Northern Ir...   Developed regions  22045
# Philippines                                         Developing regions   6051
# Pakistan                                            Developing regions    978
#
#                                                      1981   1982   1983  \
# Country
# India                                                8670   8147   7338
# China                                                6682   3308   1863
# United Kingdom of Great Britain and Northern Ir...  24796  20620  10015
# Philippines                                          5921   5249   4562
# Pakistan                                              972   1201    900
#
#                                                      1984  1985  1986  ...  \
# Country                                                                ...
# India                                                5704  4211  7150  ...
# China                                                1527  1816  1960  ...
# United Kingdom of Great Britain and Northern Ir...  10170  9564  9470  ...
# Philippines                                          3801  3150  4166  ...
# Pakistan                                              668   514   691  ...
#
#                                                      2005   2006   2007  \
# Country
# India                                               36210  33848  28742
# China                                               42584  33518  27642
# United Kingdom of Great Britain and Northern Ir...   7258   7140   8216
# Philippines                                         18139  18400  19837
# Pakistan                                            14314  13127  10124
#
#                                                      2008   2009   2010  \
# Country
# India                                               28261  29456  34235
# China                                               30037  29622  30391
# United Kingdom of Great Britain and Northern Ir...   8979   8876   8724
# Philippines                                         24887  28573  38617
# Pakistan                                             8994   7217   6811
#
#                                                      2011   2012   2013  \
# Country
# India                                               27509  30933  33087
# China                                               28502  33024  34129
# United Kingdom of Great Britain and Northern Ir...   6204   6195   5827
# Philippines                                         36765  34315  29544
# Pakistan                                             7468  11227  12603
#
#                                                      Total
# Country
# India                                               691904
# China                                               659962
# United Kingdom of Great Britain and Northern Ir...  551500
# Philippines                                         511391
# Pakistan                                            241600
#
# [5 rows x 38 columns]

# %%
df_top5 = df_top5[years].transpose()
df_top5.index = df_top5.index.map(int)

# %%
df_top5.plot(kind='line', figsize=(14, 8))
plt.title('Top 5 countries immigration')
plt.ylabel('No of immigrants')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# # Area Plots

# %%
df = pd.read_excel(
    'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx',
    sheet_name='Canada by Citizenship',
    skiprows=range(20),
    skipfooter=2)

df.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
df.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df['Total'] = df.sum(axis=1)
df.set_index('Country', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 9
#       7 df.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
#       8 df.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
# ----> 9 df['Total'] = df.sum(axis=1)
#      10 df.set_index('Country', inplace=True)
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\generic.py:11512, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11493 @doc(  # type: ignore[misc]
#   11494     _num_doc,
#   11495     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   11510     **kwargs,
#   11511 ):
# > 11512     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\generic.py:11280, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11272 def sum(
#   11273     self,
#   11274     axis: Axis | None = None,
#    (...)
#   11278     **kwargs,
#   11279 ):
# > 11280     return self._min_count_stat_function(
#   11281         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   11282     )
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\generic.py:11263, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   11260 if axis is None:
#   11261     axis = self._stat_axis_number
# > 11263 return self._reduce(
#   11264     func,
#   11265     name=name,
#   11266     axis=axis,
#   11267     skipna=skipna,
#   11268     numeric_only=numeric_only,
#   11269     min_count=min_count,
#   11270 )
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\internals\managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\internals\blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\nanops.py:494, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     491         results = [func(x, **kwargs) for x in arrs]
#     492     return np.array(results)
# --> 494 return func(values, axis=axis, **kwargs)
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\pandas\core\nanops.py:652, in nansum(values, axis, skipna, min_count, mask)
#     649 elif is_timedelta64_dtype(dtype):
#     650     dtype_sum = np.dtype(np.float64)
# --> 652 the_sum = values.sum(axis, dtype=dtype_sum)
#     653 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     655 return the_sum
#
# File c:\Users\giord\anaconda3\envs\saad\lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
df.sort_values(['Total'], ascending=False, axis=0, inplace=True)

# get the top 5 entries
df_top5 = df.head()

years=list(range(1980,2014))
# transpose the dataframe
df_top5 = df_top5[years].transpose()

df_top5.head()

# %%
df_top5.plot(kind='area',
             stacked=False,
             figsize=(20,10))
plt.title('Immigration of top 5 countries')
plt.ylabel('No of immigrants')
plt.xlabel('Years')
plt.show()

# %%
df_top5.plot(kind='area',
             alpha=0.5,
             stacked=False,
             figsize=(20,10))
plt.title('Immigration of top 5 countries')
plt.ylabel('No of immigrants')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# # Histograms

# %%
df[2013].head()

# %%
count, bin_edges = np.histogram(df[2013])

# %%
count

# %%
bin_edges

# %%
df[2013].plot(kind='hist', figsize=(8, 5))
plt.title('Histogram of immigration from 195 countries')
plt.ylabel('No of countries')
plt.xlabel('No of immigrants')
plt.show()

# %%
df[2013].plot(kind='hist', figsize=(8, 5), xticks=bin_edges)
plt.title('Histogram of immigration from 195 countries')
plt.ylabel('No of countries')
plt.xlabel('No of immigrants')
plt.show()

# %% [markdown]
# Multiple Features

# %%
df.loc[['Pakistan', 'China', 'India'], years]

# %%
df.loc[['Pakistan', 'China', 'India'], years].plot.hist()
plt.show()

# %%
df_new=df.loc[['Pakistan', 'China', 'India'], years].transpose()

# %%
df_new.plot(kind='hist', figsize=(10,6))

plt.title('Hist of immgirants of three countries from 1980 to 2013')
plt.ylabel('No of years')
plt.xlabel('No of immigrants')
plt.show()

# %% [markdown]
# # Few Modifications

# %%
count, bin_edges = np.histogram(df_new,15)

df_new.plot(kind='hist',
           figsize=(10,6),
           bins=15,
           alpha=0.6,
           xticks=bin_edges,
           color=['coral','blue','green'])
plt.title('Immigration from three countries between 1980-2013')
plt.ylabel('No of years')
plt.xlabel('No of immigrants')

plt.show()

# %% [markdown]
# # Pie Charts

# %%
df_continents= df.groupby('Continent', axis=0).sum()

# %%
df_continents

# %%
df_continents['Total'].plot(kind='pie',
                           figsize=(5,6),
                           autopct='%1.1f%%',
                           startangle=90,
                           shadow=True
                           )
plt.title('Immigration to canada by continents[1980-2013]')
plt.axis('equal')
plt.show()

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list=[0.1,0,0,0,0.1,0.1]
df_continents['Total'].plot(kind='pie',
                           figsize=(15,6),
                           autopct='%1.1f%%',
                           startangle=90,
                           shadow=True,
                           labels!=None,
                           pctdistance=1.12,
                           colors=colors_list,
                           explode=explode_list)
plt.title('Immigration to canada by continents[1980-2013]')
plt.axis('equal')
plt.legend(labels=df_continents.index, loc='upper left')
plt.show()

# %% [markdown]
# # Part D- Overview of Time Series Parameters

# %% [markdown]
# # 1-Correlation

# %%
df

# %%
df.corr()

# %%
df[1980].corr(df[1981])

# %% [markdown]
# # 2- MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error
y_true=[3,-2.5,2,7]
y_pred = [2.5,2.9,0,8]
mean_absolute_percentage_error(y_true,y_pred)

# %% [markdown]
# # 3- MAE

# %%
from sklearn.metrics import mean_absolute_error as mae
y_true=[3,-2.5,2,7]
y_pred = [2.5,2.9,0,8]
mae(y_true,y_pred)

# %% [markdown]
# # 4- RMSE

# %%
from sklearn.metrics import mean_absolute_error as mae
import math
y_true=[3,-2.5,2,7]
y_pred = [2.5,2.9,0,8]
MSE = mae(y_true,y_pred)
RMSE = math.sqrt(MSE)
print(RMSE)
